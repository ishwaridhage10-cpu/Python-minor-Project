# %% [markdown]
# <a href="https://colab.research.google.com/github/ishwaridhage10-cpu/Python-minor-Project/blob/main/Unique_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

try:
    sentence = input("Enter a sentence: ")

    words = sentence.split()

    unique_words = set(words)

    sorted_words = sorted(unique_words)

    print("Unique words in sorted order:")
    for word in sorted_words:
        print(word)

    total_unique = len(unique_words)
    result = math.pow(total_unique, 2)

    print("Number of unique words:", total_unique)
    print("Unique words raised to power 2:", result)

except Exception as e:
    print("An error occurred:", e)
# Out:
# Enter a sentence: My name is ishwari
# Unique words in sorted order:
# My
# is
# ishwari
# name
# Number of unique words: 4
# Unique words raised to power 2: 16.0

# %% [markdown]
# <a href="https://colab.research.google.com/github/ishwaridhage10-cpu/Python-minor-Project/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def analyze_string(s):
    print("Length of the string:", len(s))

    print("Reversed string:", s[::-1])

    vowels = "aeiou"
    count = 0

    for ch in s.lower():
        if ch in vowels:
            count += 1

    print("Number of vowels:", count)

    print("\nCharacter with Positive and Negative Indices:")
    for i in range(len(s)):
        print(f"Character: {s[i]}, Positive Index: {i}, Negative Index: {i - len(s)}")

user_string = input("Enter a string: ")

if user_string == "":
    print("Error: Empty string is not allowed.")
else:
    analyze_string(user_string)
# Out:
# Enter a string: Arya
# Length of the string: 4
# Reversed string: ayrA
# Number of vowels: 2
#
# Character with Positive and Negative Indices:
# Character: A, Positive Index: 0, Negative Index: -4
# Character: r, Positive Index: 1, Negative Index: -3
# Character: y, Positive Index: 2, Negative Index: -2
# Character: a, Positive Index: 3, Negative Index: -1

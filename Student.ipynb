# %% [markdown]
# <a href="https://colab.research.google.com/github/ishwaridhage10-cpu/Python-minor-Project/blob/main/Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:

    def __init__(self, name, roll_no):
        self.name = name
        self.roll_no = roll_no
        self.marks_list = []

    def add_mark(self, mark):
        try:
            if mark < 0 or mark > 100:
                raise ValueError("Marks should be between 0 and 100.")

            self.marks_list.append(mark)
            print("Mark added successfully.")

        except ValueError as e:
            print("Error:", e)

    def get_average(self):
        if len(self.marks_list) == 0:
            return 0
        return sum(self.marks_list) / len(self.marks_list)

    def display_info(self):
        print("\n--- Student Information ---")
        print("Name:", self.name)
        print("Roll No:", self.roll_no)
        print("Marks:", self.marks_list)
        print("Average Marks:", self.get_average())

try:
    name = input("Enter student name: ")
    roll_no = input("Enter roll number: ")

    student = Student(name, roll_no)

    for i in range(5):
        try:
            mark = float(input(f"Enter mark {i + 1}: "))
            student.add_mark(mark)

        except ValueError:
            print("Please enter a valid numeric value.")

    student.display_info()

except Exception as e:
    print("An error occurred:", e)
# Out:
# Enter student name: Ishwari
# Enter roll number: 101
# Enter mark 1: 45
# Mark added successfully.
# Enter mark 2: 67
# Mark added successfully.
# Enter mark 3: 89
# Mark added successfully.
# Enter mark 4: 55
# Mark added successfully.
# Enter mark 5: 99
# Mark added successfully.
#
# --- Student Information ---
# Name: Ishwari
# Roll No: 101
# Marks: [45.0, 67.0, 89.0, 55.0, 99.0]
# Average Marks: 71.0
